# %%
import requests
import bs4
import pandas

print("requests version:", requests.__version__)
print("beautifulsoup4 version:", bs4.__version__)
print("pandas version:", pandas.__version__)
# Out:
# requests version: 2.32.5
# beautifulsoup4 version: 4.13.5
# pandas version: 2.3.1

# %% [markdown]
# <tr style="cursor:pointer"><td><div class="BasePopover_base__T5yOf popover-base"><svg viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" height="1em" width="1em" class="sc-65e7f566-0 fUCMsK c-i" loading="lazy" decode="async" priority="low"><use href="#star"></use></svg></div></td><td style="text-align:start"><p color="text2" font-size="14" data-sensors-click="true" class="sc-71024e3e-0 biekbf">1</p></td><td style="text-align:start"><div display="flex" class="sc-4c05d6ef-0 bLqliP"><a href="/currencies/bitcoin/" class="cmc-link"><span data-sensors-click="true" class="sc-65e7f566-0 sc-ddaafcf5-0 eQBACe enyVEn coin-item"><img class="coin-logo" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1.png" loading="lazy" decoding="async" fetchpriority="low" alt="BTC logo"><div class="sc-65e7f566-0 sc-ddaafcf5-1 eQBACe GYriK"><div class="sc-65e7f566-0 sc-ddaafcf5-2 eQBACe hrmnMs  hide-ranking-number"><p class="sc-65e7f566-0 iPbTJf coin-item-name">Bitcoin</p><div data-nosnippet="true" class="sc-ddaafcf5-3 dwlLOs"><p class="sc-65e7f566-0 byYAWx coin-item-symbol">BTC</p></div></div></div></span></a><div class="sc-4c05d6ef-0 jHuabS"><div style="display: contents;"><div class="BasePopover_base__T5yOf popover-base"><button class="sc-65e7f566-0 hxVVPR BaseButton_base__34gwo bt-base BaseButton_t-default__8BIzz BaseButton_size-sm__oHKNE BaseButton_v-secondary__0ChW8 BaseButton_vd__gUkWt"><div data-role="btn-content" class="sc-65e7f566-0 jpqzzO BaseButton_btnContentWrapper__vm2Ue" style=""><div data-role="btn-content-item" class="sc-65e7f566-0 eQBACe BaseButton_labelWrapper___Wzzw">Buy</div></div><div class="sc-65e7f566-0 eQBACe BaseButton_loadingIndicatorWrapper__H2_qY" style=""><div class="sc-65e7f566-0 eQBACe BaseButton_loadingEl__txE0m"></div></div></button></div></div></div></div></td><td style="text-align:end"><div class="sc-142c02c-0 lmjbLF"><span>$111,785.62</span></div></td><td style="text-align:end"><span class="sc-d5c03ba0-0 dJLZma"><span class="icon-Caret-down" style="width:12px;height:18px;display:inline-block"></span>0.03%</span></td><td style="text-align:end"><span class="sc-d5c03ba0-0 ivIsIp"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>1.87%</span></td><td style="text-align:end"><span class="sc-d5c03ba0-0 dJLZma"><span class="icon-Caret-down" style="width:12px;height:18px;display:inline-block"></span>2.12%</span></td><td style="text-align:end"><p color="text" style="white-space:nowrap" font-size="1" data-sensors-click="true" class="sc-71024e3e-0 fOLOxZ"><span class="sc-11478e5d-0 chpohi">$2.23T</span><span data-nosnippet="true" class="sc-11478e5d-1 jfwGHx">$2,225,912,311,754</span></p></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-8dd8fbb5-0 dlQYLv urcFe"><a href="/currencies/bitcoin/#markets" class="cmc-link"><p font-size="1" class="sc-71024e3e-0 fOLOxZ font_weight_500" color="text" data-sensors-click="true">$64,414,509,369</p></a><div data-nosnippet="true"><p color="text2" font-size="0" data-sensors-click="true" class="sc-71024e3e-0 cuNNJt">575.03K</p></div></div></td><td style="text-align:end"><div class="BasePopover_base__T5yOf popover-base"><div style="width:140px" class="sc-c594afdb-0 iMjiTG circulating-supply-cell"><div class="circulating-supply-value"><span>19.91M</span> <!-- -->BTC</div><div class="PercentageBar_wrapper___KjMj"><div class="PercentageBar_overlay-bar__Jmn3C" style="background-color:var(--c-color-gray-300);width:94.82%;z-index:0"></div></div></div></div></td><td style="text-align:end"><img src="https://s3.coinmarketcap.com/generated/sparklines/web/7d/2781/1.svg" alt="bitcoin-7d-price-graph" class="sc-db1da501-0 ebVlnd" loading="lazy"></td></tr>

# %% [markdown]
# <p class="sc-65e7f566-0 iPbTJf coin-item-name">Ethereum</p>
# sc-65e7f566-0 iPbTJf coin-item-name

# %% [markdown]
# sc-65e7f566-0 byYAWx coin-item-symbol
# <p class="sc-65e7f566-0 byYAWx coin-item-symbol">ETH</p>

# %%
<span data-nosnippet="true" class="sc-11478e5d-1 jfwGHx">$2,229,416,720,793</span>
<span data-nosnippet="true" class="sc-11478e5d-1 jfwGHx">$557,592,043,063</span>

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': 'Mozilla/5.0'
}

# List to collect data
crypto_data = []

page = 1  # Make sure 'page' is defined
url = f'https://coinmarketcap.com/?page={page}'
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

rows = soup.find_all('tr')

records_on_page = 0

for row in rows:
    tds = row.find_all('td')
    if len(tds) > 8:
        data = {}

        # Coin Name
        name_tag = tds[2].find('p', class_='sc-65e7f566-0 iPbTJf coin-item-name')
        data['Coin Name'] = name_tag.text.strip() if name_tag else 'N/A'

        # Symbol
        symbol_tag = tds[2].find('p', class_='sc-65e7f566-0 byYAWx coin-item-symbol')
        data['Symbol'] = symbol_tag.text.strip() if symbol_tag else 'N/A'

        # Price
        price_tag = tds[3].find('span')
        data['Price (USD)'] = price_tag.text.strip() if price_tag else 'N/A'

        # 1h Change
        change_tag = tds[4].find('span')
        data['1h Change (%)'] = change_tag.text.strip() if change_tag else 'N/A'

        # Market Cap
        market_cap_tag = tds[7].find('span',class_="sc-11478e5d-1 jfwGHx")
        data['Market Cap'] = market_cap_tag.text.strip() if market_cap_tag else 'N/A'

        # Volume (24h)
        volume_container = tds[8]
        volume_usd_tag = volume_container.find('a')
        if volume_usd_tag:
            volume_usd_p = volume_usd_tag.find('p')
            data['Volume (24h) USD'] = volume_usd_p.text.strip() if volume_usd_p else 'N/A'
        else:
            data['Volume (24h) USD'] = 'N/A'

        # Circulating Supply
        supply_tag = tds[9].find('span')
        data['Circulating Supply'] = supply_tag.text.strip() if supply_tag else 'N/A'

        crypto_data.append(data)

# %%
crypto_data
# Out:
# [{'Coin Name': 'CoinMarketCap 20 Index DTF',
#   'Symbol': 'CMC20',
#   'Price (USD)': '$185.58',
#   '1h Change (%)': '0.22%',
#   'Market Cap': '$6,346,916',
#   'Volume (24h) USD': '$1,063,287',
#   'Circulating Supply': '34.19K'},
#  {'Coin Name': 'Bitcoin',
#   'Symbol': 'BTC',
#   'Price (USD)': '$88,873.90',
#   '1h Change (%)': '0.45%',
#   'Market Cap': '$1,774,879,515,324',
#   'Volume (24h) USD': '$15,374,831,895',
#   'Circulating Supply': '19.96M'},
#  {'Coin Name': 'Ethereum',
#   'Symbol': 'ETH',
#   'Price (USD)': '$2,999.95',
#   '1h Change (%)': '0.30%',
#   'Market Cap': '$361,868,747,215',
#   'Volume (24h) USD': '$7,657,199,531',
#   'Circulating Supply': '120.69M'},
#  {'Coin Name': 'Tether',
#   'Symbol': 'USDT',
#   'Price (USD)': '$0.9997',
#   '1h Change (%)': '0.03%',
#   'Market Cap': '$186,751,039,178',
#   'Volume (24h) USD': '$48,086,332,494',
#   'Circulating Supply': '186.82B'},
#  {'Coin Name': 'XRP',
#   'Symbol': 'XRP',
#   'Price (USD)': '$1.94',
#   '1h Change (%)': '0.32%',
#   'Market Cap': '$117,750,816,347',
#   'Volume (24h) USD': '$2,402,308,187',
#   'Circulating Supply': '60.57B'},
#  {'Coin Name': 'BNB',
#   'Symbol': 'BNB',
#   'Price (USD)': '$854.90',
#   '1h Change (%)': '0.04%',
#   'Market Cap': '$117,737,606,235',
#   'Volume (24h) USD': '$1,362,017,029',
#   'Circulating Supply': '137.73M'},
#  {'Coin Name': 'USDC',
#   'Symbol': 'USDC',
#   'Price (USD)': '$0.9999',
#   '1h Change (%)': '0.04%',
#   'Market Cap': '$77,061,439,786',
#   'Volume (24h) USD': '$3,888,376,379',
#   'Circulating Supply': '77.06B'},
#  {'Coin Name': 'Solana',
#   'Symbol': 'SOL',
#   'Price (USD)': '$126.15',
#   '1h Change (%)': '0.45%',
#   'Market Cap': '$70,938,641,734',
#   'Volume (24h) USD': '$1,729,364,741',
#   'Circulating Supply': '562.29M'},
#  {'Coin Name': 'TRON',
#   'Symbol': 'TRX',
#   'Price (USD)': '$0.2844',
#   '1h Change (%)': '0.13%',
#   'Market Cap': '$26,931,777,340',
#   'Volume (24h) USD': '$444,117,687',
#   'Circulating Supply': '94.68B'},
#  {'Coin Name': 'Dogecoin',
#   'Symbol': 'DOGE',
#   'Price (USD)': '$0.1327',
#   '1h Change (%)': '0.14%',
#   'Market Cap': '$22,299,371,292',
#   'Volume (24h) USD': '$508,035,927',
#   'Circulating Supply': '167.98B'},
#  {'Coin Name': 'Cardano',
#   'Symbol': 'ADA',
#   'Price (USD)': '$0.3733',
#   '1h Change (%)': '0.67%',
#   'Market Cap': '$13,414,057,093',
#   'Volume (24h) USD': '$324,432,275',
#   'Circulating Supply': '35.92B'},
#  {'Coin Name': 'Bitcoin Cash',
#   'Symbol': 'BCH',
#   'Price (USD)': '$587.39',
#   '1h Change (%)': '0.29%',
#   'Market Cap': '$11,730,181,538',
#   'Volume (24h) USD': '$308,122,409',
#   'Circulating Supply': '19.96M'},
#  {'Coin Name': 'Chainlink',
#   'Symbol': 'LINK',
#   'Price (USD)': '$12.64',
#   '1h Change (%)': '0.28%',
#   'Market Cap': '$8,951,958,384',
#   'Volume (24h) USD': '$263,063,085',
#   'Circulating Supply': '708.09M'},
#  {'Coin Name': 'Monero',
#   'Symbol': 'XMR',
#   'Price (USD)': '$464.61',
#   '1h Change (%)': '0.58%',
#   'Market Cap': '$8,570,692,229',
#   'Volume (24h) USD': '$211,647,626',
#   'Circulating Supply': '18.44M'},
#  {'Coin Name': 'Hyperliquid',
#   'Symbol': 'HYPE',
#   'Price (USD)': '$24.17',
#   '1h Change (%)': '0.49%',
#   'Market Cap': '$8,138,009,852',
#   'Volume (24h) USD': '$154,656,590',
#   'Circulating Supply': '336.68M'},
#  {'Coin Name': 'The Graph',
#   'Symbol': 'GRT',
#   'Price (USD)': '$0.03739',
#   '1h Change (%)': '0.16%',
#   'Market Cap': '$398,468,593',
#   'Volume (24h) USD': '$12,435,277',
#   'Circulating Supply': '10.65B'},
#  {'Coin Name': 'JUST',
#   'Symbol': 'JST',
#   'Price (USD)': '$0.03987',
#   '1h Change (%)': '0.14%',
#   'Market Cap': '$394,775,367',
#   'Volume (24h) USD': '$27,993,505',
#   'Circulating Supply': '9.9B'},
#  {'Coin Name': 'FLOKI',
#   'Symbol': 'FLOKI',
#   'Price (USD)': '$0.00004119',
#   '1h Change (%)': '0.10%',
#   'Market Cap': '$393,051,311',
#   'Volume (24h) USD': '$19,479,741',
#   'Circulating Supply': '9.54T'},
#  {'Coin Name': 'BitTorrent [New]',
#   'Symbol': 'BTT',
#   'Price (USD)': '$0.063967',
#   '1h Change (%)': '0.11%',
#   'Market Cap': '$391,190,063',
#   'Volume (24h) USD': '$10,453,055',
#   'Circulating Supply': '986.06T'},
#  {'Coin Name': 'Sun [New]',
#   'Symbol': 'SUN',
#   'Price (USD)': '$0.02020',
#   '1h Change (%)': '0.09%',
#   'Market Cap': '$387,723,195',
#   'Volume (24h) USD': '$18,414,633',
#   'Circulating Supply': '19.18B'},
#  {'Coin Name': 'Chiliz',
#   'Symbol': 'CHZ',
#   'Price (USD)': '$0.03813',
#   '1h Change (%)': '0.10%',
#   'Market Cap': '$387,900,122',
#   'Volume (24h) USD': '$134,840,700',
#   'Circulating Supply': '10.17B'},
#  {'Coin Name': 'DoubleZero',
#   'Symbol': '2Z',
#   'Price (USD)': '$0.1086',
#   '1h Change (%)': '0.64%',
#   'Market Cap': '$377,255,611',
#   'Volume (24h) USD': '$9,903,498',
#   'Circulating Supply': '3.47B'},
#  {'Coin Name': 'IOTA',
#   'Symbol': 'IOTA',
#   'Price (USD)': '$0.08991',
#   '1h Change (%)': '0.01%',
#   'Market Cap': '$377,179,775',
#   'Volume (24h) USD': '$9,340,440',
#   'Circulating Supply': '4.19B'},
#  {'Coin Name': 'Maple Finance',
#   'Symbol': 'SYRUP',
#   'Price (USD)': '$0.3286',
#   '1h Change (%)': '0.52%',
#   'Market Cap': '$375,506,614',
#   'Volume (24h) USD': '$26,876,303',
#   'Circulating Supply': '1.14B'},
#  {'Coin Name': 'Bitcoin SV',
#   'Symbol': 'BSV',
#   'Price (USD)': '$18.75',
#   '1h Change (%)': '0.16%',
#   'Market Cap': '$374,392,349',
#   'Volume (24h) USD': '$10,572,775',
#   'Circulating Supply': '19.96M'},
#  {'Coin Name': 'Conflux',
#   'Symbol': 'CFX',
#   'Price (USD)': '$0.07198',
#   '1h Change (%)': '0.27%',
#   'Market Cap': '$371,839,517',
#   'Volume (24h) USD': '$11,179,413',
#   'Circulating Supply': '5.16B'},
#  {'Coin Name': 'Kaia',
#   'Symbol': 'KAIA',
#   'Price (USD)': '$0.05992',
#   '1h Change (%)': '0.33%',
#   'Market Cap': '$371,451,634',
#   'Volume (24h) USD': '$15,957,315',
#   'Circulating Supply': '6.19B'},
#  {'Coin Name': 'Ethereum Name Service',
#   'Symbol': 'ENS',
#   'Price (USD)': '$9.72',
#   '1h Change (%)': '0.22%',
#   'Market Cap': '$371,411,275',
#   'Volume (24h) USD': '$19,074,265',
#   'Circulating Supply': '38.19M'},
#  {'Coin Name': 'Trust Wallet Token',
#   'Symbol': 'TWT',
#   'Price (USD)': '$0.8390',
#   '1h Change (%)': '0.47%',
#   'Market Cap': '$360,677,516',
#   'Volume (24h) USD': '$15,728,667',
#   'Circulating Supply': '429.86M'},
#  {'Coin Name': 'AINFT',
#   'Symbol': 'NFT',
#   'Price (USD)': '$0.063494',
#   '1h Change (%)': '1.03%',
#   'Market Cap': '$349,467,271',
#   'Volume (24h) USD': '$18,414,383',
#   'Circulating Supply': '999.99T'},
#  {'Coin Name': 'The Graph',
#   'Symbol': 'GRT',
#   'Price (USD)': '$0.03739',
#   '1h Change (%)': '0.16%',
#   'Market Cap': '$398,468,593',
#   'Volume (24h) USD': '$12,435,277',
#   'Circulating Supply': '10.65B'},
#  {'Coin Name': 'JUST',
#   'Symbol': 'JST',
#   'Price (USD)': '$0.03987',
#   '1h Change (%)': '0.14%',
#   'Market Cap': '$394,775,367',
#   'Volume (24h) USD': '$27,993,505',
#   'Circulating Supply': '9.9B'},
#  {'Coin Name': 'FLOKI',
#   'Symbol': 'FLOKI',
#   'Price (USD)': '$0.00004119',
#   '1h Change (%)': '0.10%',
#   'Market Cap': '$393,051,311',
#   'Volume (24h) USD': '$19,479,741',
#   'Circulating Supply': '9.54T'},
#  {'Coin Name': 'BitTorrent [New]',
#   'Symbol': 'BTT',
#   'Price (USD)': '$0.063967',
#   '1h Change (%)': '0.11%',
#   'Market Cap': '$391,190,063',
#   'Volume (24h) USD': '$10,453,055',
#   'Circulating Supply': '986.06T'},
#  {'Coin Name': 'Sun [New]',
#   'Symbol': 'SUN',
#   'Price (USD)': '$0.02020',
#   '1h Change (%)': '0.09%',
#   'Market Cap': '$387,723,195',
#   'Volume (24h) USD': '$18,414,633',
#   'Circulating Supply': '19.18B'},
#  {'Coin Name': 'Chiliz',
#   'Symbol': 'CHZ',
#   'Price (USD)': '$0.03813',
#   '1h Change (%)': '0.10%',
#   'Market Cap': '$387,900,122',
#   'Volume (24h) USD': '$134,840,700',
#   'Circulating Supply': '10.17B'},
#  {'Coin Name': 'DoubleZero',
#   'Symbol': '2Z',
#   'Price (USD)': '$0.1086',
#   '1h Change (%)': '0.64%',
#   'Market Cap': '$377,255,611',
#   'Volume (24h) USD': '$9,903,498',
#   'Circulating Supply': '3.47B'},
#  {'Coin Name': 'IOTA',
#   'Symbol': 'IOTA',
#   'Price (USD)': '$0.08991',
#   '1h Change (%)': '0.01%',
#   'Market Cap': '$377,179,775',
#   'Volume (24h) USD': '$9,340,440',
#   'Circulating Supply': '4.19B'},
#  {'Coin Name': 'Maple Finance',
#   'Symbol': 'SYRUP',
#   'Price (USD)': '$0.3286',
#   '1h Change (%)': '0.52%',
#   'Market Cap': '$375,506,614',
#   'Volume (24h) USD': '$26,876,303',
#   'Circulating Supply': '1.14B'},
#  {'Coin Name': 'Bitcoin SV',
#   'Symbol': 'BSV',
#   'Price (USD)': '$18.75',
#   '1h Change (%)': '0.16%',
#   'Market Cap': '$374,392,349',
#   'Volume (24h) USD': '$10,572,775',
#   'Circulating Supply': '19.96M'},
#  {'Coin Name': 'Conflux',
#   'Symbol': 'CFX',
#   'Price (USD)': '$0.07198',
#   '1h Change (%)': '0.27%',
#   'Market Cap': '$371,839,517',
#   'Volume (24h) USD': '$11,179,413',
#   'Circulating Supply': '5.16B'},
#  {'Coin Name': 'Kaia',
#   'Symbol': 'KAIA',
#   'Price (USD)': '$0.05992',
#   '1h Change (%)': '0.33%',
#   'Market Cap': '$371,451,634',
#   'Volume (24h) USD': '$15,957,315',
#   'Circulating Supply': '6.19B'},
#  {'Coin Name': 'Ethereum Name Service',
#   'Symbol': 'ENS',
#   'Price (USD)': '$9.72',
#   '1h Change (%)': '0.22%',
#   'Market Cap': '$371,411,275',
#   'Volume (24h) USD': '$19,074,265',
#   'Circulating Supply': '38.19M'},
#  {'Coin Name': 'Trust Wallet Token',
#   'Symbol': 'TWT',
#   'Price (USD)': '$0.8390',
#   '1h Change (%)': '0.47%',
#   'Market Cap': '$360,677,516',
#   'Volume (24h) USD': '$15,728,667',
#   'Circulating Supply': '429.86M'},
#  {'Coin Name': 'AINFT',
#   'Symbol': 'NFT',
#   'Price (USD)': '$0.063494',
#   '1h Change (%)': '1.03%',
#   'Market Cap': '$349,467,271',
#   'Volume (24h) USD': '$18,414,383',
#   'Circulating Supply': '999.99T'}]

# %%
import pandas as pd
df=pd.DataFrame(crypto_data)
df
# Out:
#                      Coin Name Symbol  Price (USD) 1h Change (%)  \
# 0   CoinMarketCap 20 Index DTF  CMC20      $185.58         0.22%
# 1                      Bitcoin    BTC   $88,873.90         0.45%
# 2                     Ethereum    ETH    $2,999.95         0.30%
# 3                       Tether   USDT      $0.9997         0.03%
# 4                          XRP    XRP        $1.94         0.32%
# 5                          BNB    BNB      $854.90         0.04%
# 6                         USDC   USDC      $0.9999         0.04%
# 7                       Solana    SOL      $126.15         0.45%
# 8                         TRON    TRX      $0.2844         0.13%
# 9                     Dogecoin   DOGE      $0.1327         0.14%
# 10                     Cardano    ADA      $0.3733         0.67%
# 11                Bitcoin Cash    BCH      $587.39         0.29%
# 12                   Chainlink   LINK       $12.64         0.28%
# 13                      Monero    XMR      $464.61         0.58%
# 14                 Hyperliquid   HYPE       $24.17         0.49%
# 15                   The Graph    GRT     $0.03739         0.16%
# 16                        JUST    JST     $0.03987         0.14%
# 17                       FLOKI  FLOKI  $0.00004119         0.10%
# 18            BitTorrent [New]    BTT    $0.063967         0.11%
# 19                   Sun [New]    SUN     $0.02020         0.09%
# 20                      Chiliz    CHZ     $0.03813         0.10%
# 21                  DoubleZero     2Z      $0.1086         0.64%
# 22                        IOTA   IOTA     $0.08991         0.01%
# 23               Maple Finance  SYRUP      $0.3286         0.52%
# 24                  Bitcoin SV    BSV       $18.75         0.16%
# 25                     Conflux    CFX     $0.07198         0.27%
# 26                        Kaia   KAIA     $0.05992         0.33%
# 27       Ethereum Name Service    ENS        $9.72         0.22%
# 28          Trust Wallet Token    TWT      $0.8390         0.47%
# 29                       AINFT    NFT    $0.063494         1.03%
# 30                   The Graph    GRT     $0.03739         0.16%
# 31                        JUST    JST     $0.03987         0.14%
# 32                       FLOKI  FLOKI  $0.00004119         0.10%
# 33            BitTorrent [New]    BTT    $0.063967         0.11%
# 34                   Sun [New]    SUN     $0.02020         0.09%
# 35                      Chiliz    CHZ     $0.03813         0.10%
# 36                  DoubleZero     2Z      $0.1086         0.64%
# 37                        IOTA   IOTA     $0.08991         0.01%
# 38               Maple Finance  SYRUP      $0.3286         0.52%
# 39                  Bitcoin SV    BSV       $18.75         0.16%
# 40                     Conflux    CFX     $0.07198         0.27%
# 41                        Kaia   KAIA     $0.05992         0.33%
# 42       Ethereum Name Service    ENS        $9.72         0.22%
# 43          Trust Wallet Token    TWT      $0.8390         0.47%
# 44                       AINFT    NFT    $0.063494         1.03%
#
#             Market Cap Volume (24h) USD Circulating Supply
# 0           $6,346,916       $1,063,287             34.19K
# 1   $1,774,879,515,324  $15,374,831,895             19.96M
# 2     $361,868,747,215   $7,657,199,531            120.69M
# 3     $186,751,039,178  $48,086,332,494            186.82B
# 4     $117,750,816,347   $2,402,308,187             60.57B
# 5     $117,737,606,235   $1,362,017,029            137.73M
# 6      $77,061,439,786   $3,888,376,379             77.06B
# 7      $70,938,641,734   $1,729,364,741            562.29M
# 8      $26,931,777,340     $444,117,687             94.68B
# 9      $22,299,371,292     $508,035,927            167.98B
# 10     $13,414,057,093     $324,432,275             35.92B
# 11     $11,730,181,538     $308,122,409             19.96M
# 12      $8,951,958,384     $263,063,085            708.09M
# 13      $8,570,692,229     $211,647,626             18.44M
# 14      $8,138,009,852     $154,656,590            336.68M
# 15        $398,468,593      $12,435,277             10.65B
# 16        $394,775,367      $27,993,505               9.9B
# 17        $393,051,311      $19,479,741              9.54T
# 18        $391,190,063      $10,453,055            986.06T
# 19        $387,723,195      $18,414,633             19.18B
# 20        $387,900,122     $134,840,700             10.17B
# 21        $377,255,611       $9,903,498              3.47B
# 22        $377,179,775       $9,340,440              4.19B
# 23        $375,506,614      $26,876,303              1.14B
# 24        $374,392,349      $10,572,775             19.96M
# 25        $371,839,517      $11,179,413              5.16B
# 26        $371,451,634      $15,957,315              6.19B
# 27        $371,411,275      $19,074,265             38.19M
# 28        $360,677,516      $15,728,667            429.86M
# 29        $349,467,271      $18,414,383            999.99T
# 30        $398,468,593      $12,435,277             10.65B
# 31        $394,775,367      $27,993,505               9.9B
# 32        $393,051,311      $19,479,741              9.54T
# 33        $391,190,063      $10,453,055            986.06T
# 34        $387,723,195      $18,414,633             19.18B
# 35        $387,900,122     $134,840,700             10.17B
# 36        $377,255,611       $9,903,498              3.47B
# 37        $377,179,775       $9,340,440              4.19B
# 38        $375,506,614      $26,876,303              1.14B
# 39        $374,392,349      $10,572,775             19.96M
# 40        $371,839,517      $11,179,413              5.16B
# 41        $371,451,634      $15,957,315              6.19B
# 42        $371,411,275      $19,074,265             38.19M
# 43        $360,677,516      $15,728,667            429.86M
# 44        $349,467,271      $18,414,383            999.99T

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    'User-Agent': 'Mozilla/5.0'
}

crypto_data = []

for page in range(1, 21):
    print(f"Scraping page {page}...")

    url = f'https://coinmarketcap.com/?page={page}'
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = soup.find_all('tr')

    records_on_page = 0

    for row in rows:
        tds = row.find_all('td')
        if len(tds) > 8:
            data = {}

    
            name_tag = tds[2].find('p', class_='sc-65e7f566-0 iPbTJf coin-item-name')
            data['Coin Name'] = name_tag.text.strip() if name_tag else 'N/A'

            
            symbol_tag = tds[2].find('p', class_='sc-65e7f566-0 byYAWx coin-item-symbol')
            data['Symbol'] = symbol_tag.text.strip() if symbol_tag else 'N/A'

        
            price_tag = tds[3].find('span')
            data['Price (USD)'] = price_tag.text.strip() if price_tag else 'N/A'

            
            change_tag = tds[4].find('span')
            data['1h Change (%)'] = change_tag.text.strip() if change_tag else 'N/A'

            
            market_cap_tag = tds[7].find('span',class_="sc-11478e5d-1 jfwGHx")
            data['Market Cap'] = market_cap_tag.text.strip() if market_cap_tag else 'N/A'

            
            volume_container = tds[8]
            volume_usd_tag = volume_container.find('a')
            if volume_usd_tag:
                volume_usd_p = volume_usd_tag.find('p')
                data['Volume (24h) USD'] = volume_usd_p.text.strip() if volume_usd_p else 'N/A'
            else:
                data['Volume (24h) USD'] = 'N/A'

            
            supply_tag = tds[9].find('span')
            data['Circulating Supply'] = supply_tag.text.strip() if supply_tag else 'N/A'

            crypto_data.append(data)
            records_on_page += 1

    print(f" ✅ Records scraped on page {page}: {records_on_page}")
    time.sleep(5)
# Out:
# Scraping page 1...
#  ✅ Records scraped on page 1: 15
# Scraping page 2...
#  ✅ Records scraped on page 2: 15
# Scraping page 3...
#  ✅ Records scraped on page 3: 15
# Scraping page 4...
#  ✅ Records scraped on page 4: 15
# Scraping page 5...
#  ✅ Records scraped on page 5: 15
# Scraping page 6...
#  ✅ Records scraped on page 6: 15
# Scraping page 7...
#  ✅ Records scraped on page 7: 15
# Scraping page 8...
#  ✅ Records scraped on page 8: 15
# Scraping page 9...
#  ✅ Records scraped on page 9: 15
# Scraping page 10...
#  ✅ Records scraped on page 10: 15
# Scraping page 11...
#  ✅ Records scraped on page 11: 15
# Scraping page 12...
#  ✅ Records scraped on page 12: 15
# Scraping page 13...
#  ✅ Records scraped on page 13: 15
# Scraping page 14...
#  ✅ Records scraped on page 14: 15
# Scraping page 15...
#  ✅ Records scraped on page 15: 15
# Scraping page 16...
#  ✅ Records scraped on page 16: 15
# Scraping page 17...
#  ✅ Records scraped on page 17: 15
# Scraping page 18...
#  ✅ Records scraped on page 18: 15
# Scraping page 19...
#  ✅ Records scraped on page 19: 15
# Scraping page 20...
#  ✅ Records scraped on page 20: 15

# %%
import pandas as pd
crypto_df = pd.DataFrame(crypto_data)


print(crypto_df.head(10))
print(f"\n✅ Total records scraped: {len(crypto_df)}")
# Out:
#                     Coin Name Symbol Price (USD) 1h Change (%)  \
# 0  CoinMarketCap 20 Index DTF  CMC20     $186.18         0.41%
# 1                     Bitcoin    BTC  $88,776.81         0.22%
# 2                    Ethereum    ETH   $3,000.86         0.38%
# 3                      Tether   USDT     $0.9995         0.01%
# 4                         BNB    BNB     $858.00         0.54%
# 5                         XRP    XRP       $1.94         0.50%
# 6                        USDC   USDC     $0.9997         0.00%
# 7                      Solana    SOL     $126.42         0.65%
# 8                        TRON    TRX     $0.2847         0.21%
# 9                    Dogecoin   DOGE     $0.1326         0.18%
#
#            Market Cap Volume (24h) USD Circulating Supply
# 0          $6,367,617       $1,082,622             34.19K
# 1  $1,773,702,163,982  $15,613,428,628             19.96M
# 2    $362,443,598,330   $8,032,435,373            120.69M
# 3    $186,743,665,599  $48,877,647,609            186.82B
# 4    $118,177,198,602   $1,378,495,286            137.73M
# 5    $117,762,851,092   $2,410,087,082             60.57B
# 6     $77,050,723,858   $3,949,227,085             77.06B
# 7     $71,088,918,483   $1,764,111,771            562.29M
# 8     $26,957,866,416     $444,915,602             94.68B
# 9     $22,291,240,696     $515,506,778            167.98B
#
# ✅ Total records scraped: 300

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/250.9 kB 960.0 kB/s eta 0:00:01
#    --------- ------------------------------ 61.4/250.9 kB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 122.9/250.9 kB 1.2 MB/s eta 0:00:01
#    ------------------- -------------------- 122.9/250.9 kB 1.2 MB/s eta 0:00:01
#    ----------------------- -------------- 153.6/250.9 kB 654.6 kB/s eta 0:00:01
#    -------------------------------------  245.8/250.9 kB 942.1 kB/s eta 0:00:01
#    -------------------------------------- 250.9/250.9 kB 853.4 kB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
crypto_data.to_excel("crypto_Analysis_Data.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 crypto_data.to_excel("crypto_Analysis_Data.xlsx",index=False)
#
# NameError: name 'crypto_data' is not defined
